# %%
from tkinter import *
import tkinter as tk
from tkinter.scrolledtext import ScrolledText
import requests
from tkinter import messagebox
import random
from datetime import datetime
from tkinter import filedialog

# Functions

# Total button code
def total_bills():
    # Food item prices
    chips_price = 50
    biscuit_price = 100
    frooti_price = 45
    redbull_price = 100
    cakes_price = 80
    coffee_price = 300
    tea_price = 200
    milk_price = 60

    # Cosmetic item prices
    bathsoap_price = 500
    shampoo_price = 800
    facecream_price = 450
    facewash_price = 220
    bodylotion_price = 300
    hairclip_price = 120
    hairband_price = 80
    handwash_price = 180

    # Food item quantities
    chips_q = int(chips_qty.get() or 0)
    biscuit_q = int(biscuit_qty.get() or 0)
    frooti_q = int(frooti_qty.get() or 0)
    redbull_q = int(redbull_qty.get() or 0)
    cakes_q = int(cakes_qty.get() or 0)
    coffee_q = int(coffee_qty.get() or 0)
    tea_q = int(tea_qty.get() or 0)
    milk_q = int(milk_qty.get() or 0)

    # Cosmetic item quantities
    bathsoap_q = int(bathsoap_qty.get() or 0)
    shampoo_q = int(shampoo_qty.get() or 0)
    facecream_q = int(facecream_qty.get() or 0)
    facewash_q = int(facewash_qty.get() or 0)
    bodylotion_q = int(bodylotion_qty.get() or 0)
    hairclip_q = int(hairclip_qty.get() or 0)
    hairband_q = int(hairband_qty.get() or 0)
    handwash_q = int(handwash_qty.get() or 0)

    # Total food item cost
    total_food_cost = (chips_q * chips_price) + (biscuit_q * biscuit_price) + (frooti_q * frooti_price) + \
                      (redbull_q * redbull_price) + (cakes_q * cakes_price) + (coffee_q * coffee_price) + \
                      (tea_q * tea_price) + (milk_q * milk_price)

    # Update food cost entry
    food_cost.delete(0, "end")
    food_cost.insert("end", total_food_cost)

    # Total cosmetic item cost
    total_cosmetics_cost = (bathsoap_q * bathsoap_price) + (shampoo_q * shampoo_price) + (facecream_q * facecream_price) + \
                           (facewash_q * facewash_price) + (bodylotion_q * bodylotion_price) + (hairclip_q * hairclip_price) + \
                           (hairband_q * hairband_price) + (handwash_q * handwash_price)

    # Update cosmetics cost entry
    cosmetics_cost.delete(0, "end")
    cosmetics_cost.insert("end", total_cosmetics_cost)

    # Service charge
    service_charge = 10
    service_charge_cost.delete(0, "end")
    service_charge_cost.insert(0, service_charge)

    # Paid tax
    total_paid_tax = (total_food_cost + total_cosmetics_cost) * 0.08
    paid_tax_cost.delete(0, "end")
    paid_tax_cost.insert(0, total_paid_tax)

    # Subtotal
    total_sub_cost = total_food_cost + total_cosmetics_cost + service_charge
    sub_total_cost.delete(0, "end")
    sub_total_cost.insert(0, total_sub_cost)

    # Total cost
    total_cost = total_sub_cost + total_paid_tax
    total_cost_cost.delete(0, "end")
    total_cost_cost.insert(0, total_cost)

    # Billing receipt
    date = datetime.now().date()
    bill_details.delete('1.0', END)
    bill_details.insert('1.0', f" Billno-{random.randint(100, 1000)}\t{date}\n")
    bill_details.insert(END, "Items(q)\t\t\tAmount\n")
    if chips_q > 0:
        bill_details.insert(END, f"Chips({chips_q})\t\t\t{chips_q * chips_price}\n")
    if biscuit_q > 0:
        bill_details.insert(END, f"Biscuit({biscuit_q})\t\t\t{biscuit_q * biscuit_price}\n")
    if frooti_q > 0:
        bill_details.insert(END, f"Frooti({frooti_q})\t\t\t{frooti_q * frooti_price}\n")
    if redbull_q > 0:
        bill_details.insert(END, f"Redbull({redbull_q})\t\t\t{redbull_q * redbull_price}\n")
    if cakes_q > 0:
        bill_details.insert(END, f"Cakes({cakes_q})\t\t\t{cakes_q * cakes_price}\n")
    if coffee_q > 0:
        bill_details.insert(END, f"Coffee({coffee_q})\t\t\t{coffee_q * coffee_price}\n")
    if tea_q > 0:
        bill_details.insert(END, f"Tea({tea_q})\t\t\t{tea_q * tea_price}\n")
    if milk_q > 0:
        bill_details.insert(END, f"Milk({milk_q})\t\t\t{milk_q * milk_price}\n")
    if bathsoap_q > 0:
        bill_details.insert(END, f"Bathsoap({bathsoap_q})\t\t\t{bathsoap_q * bathsoap_price}\n")
    if shampoo_q > 0:
        bill_details.insert(END, f"Shampoo({shampoo_q})\t\t\t{shampoo_q * shampoo_price}\n")
    if facecream_q > 0:
        bill_details.insert(END, f"Facecream({facecream_q})\t\t\t{facecream_q * facecream_price}\n")
    if facewash_q > 0:
        bill_details.insert(END, f"Facewash({facewash_q})\t\t\t{facewash_q * facewash_price}\n")
    if bodylotion_q > 0:
        bill_details.insert(END, f"Bodylotion({bodylotion_q})\t\t\t{bodylotion_q * bodylotion_price}\n")
    if hairclip_q > 0:
        bill_details.insert(END, f"Hairclip({hairclip_q})\t\t\t{hairclip_q * hairclip_price}\n")
    if hairband_q > 0:
        bill_details.insert(END, f"Hairband({hairband_q})\t\t\t{hairband_q * hairband_price}\n")
    if handwash_q > 0:
        bill_details.insert(END, f"Handwash({handwash_q})\t\t\t{handwash_q * handwash_price}\n")

# Save button code
def save():
    file = filedialog.asksaveasfile(mode="w", defaultextension=".txt")
    if file is None:
        return
    file_save = str(bill_details.get('1.0', END))
    file.write(file_save)
    file.close()

# Food checkbutton validation
def chips_chk():
    if chips_var.get() == 1:
        chips_qty['state'] = "normal"
    else:
        chips_qty['state'] = "disabled"

def biscuit_chk():
    if biscuit_var.get() == 1:
        biscuit_qty['state'] = "normal"
    else:
        biscuit_qty['state'] = "disabled"

def frooti_chk():
    if frooti_var.get() == 1:
        frooti_qty['state'] = "normal"
    else:
        frooti_qty['state'] = "disabled"

def redbull_chk():
    if redbull_var.get() == 1:
        redbull_qty['state'] = "normal"
    else:
        redbull_qty['state'] = "disabled"

def cakes_chk():
    if cakes_var.get() == 1:
        cakes_qty['state'] = "normal"
    else:
        cakes_qty['state'] = "disabled"

def coffee_chk():
    if coffee_var.get() == 1:
        coffee_qty['state'] = "normal"
    else:
        coffee_qty['state'] = "disabled"

def tea_chk():
    if tea_var.get() == 1:
        tea_qty['state'] = "normal"
    else:
        tea_qty['state'] = "disabled"

def milk_chk():
    if milk_var.get() == 1:
        milk_qty['state'] = "normal"
    else:
        milk_qty['state'] = "disabled"

# Cosmetics checkbutton validation
def bathsoap_chk():
    if bathsoap_var.get() == 1:
        bathsoap_qty['state'] = "normal"
    else:
        bathsoap_qty['state'] = "disabled"

def shampoo_chk():
    if shampoo_var.get() == 1:
        shampoo_qty['state'] = "normal"
    else:
        shampoo_qty['state'] = "disabled"

def facecream_chk():
    if facecream_var.get() == 1:
        facecream_qty['state'] = "normal"
    else:
        facecream_qty['state'] = "disabled"

def facewash_chk():
    if facewash_var.get() == 1:
        facewash_qty['state'] = "normal"
    else:
        facewash_qty['state'] = "disabled"

def bodylotion_chk():
    if bodylotion_var.get() == 1:
        bodylotion_qty['state'] = "normal"
    else:
        bodylotion_qty['state'] = "disabled"

def hairclip_chk():
    if hairclip_var.get() == 1:
        hairclip_qty['state'] = "normal"
    else:
        hairclip_qty['state'] = "disabled"

def hairband_chk():
    if hairband_var.get() == 1:
        hairband_qty['state'] = "normal"
    else:
        hairband_qty['state'] = "disabled"

def handwash_chk():
    if handwash_var.get() == 1:
        handwash_qty['state'] = "normal"
    else:
        handwash_qty['state'] = "disabled"

#calculator code
def nine():
    if 'error' in result.get() or '=' in result.get():
        result.delete(0, "end")
        result.insert("end", "9")
    else:
        result.insert("end","9")

def eight():
    if 'error' in result.get() or '=' in result.get():
        result.delete(0, "end")
        result.insert("end", "8")
    else:
        result.insert("end","8")


def seven():
    if 'error' in result.get() or '=' in result.get():
        result.delete(0, "end")
        result.insert("end", "7")
    else:
        result.insert("end","7")

def six():
    if 'error' in result.get() or '=' in result.get():
        result.delete(0, "end")
        result.insert("end", "6")
    else:
        result.insert("end","6")

def five():
    if 'error' in result.get() or '=' in result.get():
        result.delete(0, "end")
        result.insert("end", "5")
    else:
        result.insert("end","5")

def four():
    if 'error' in result.get() or '=' in result.get():
        result.delete(0, "end")
        result.insert("end", "4")
    else:
        result.insert("end","4")

def three():
    if 'error' in result.get() or '=' in result.get():
        result.delete(0, "end")
        result.insert("end", "3")
    else:
        result.insert("end","3")

def two():
    if 'error' in result.get() or '=' in result.get():
        result.delete(0, "end")
        result.insert("end", "2")
    else:
        result.insert("end","2")

def one():
    if 'error' in result.get() or '=' in result.get():
        result.delete(0, "end")
        result.insert("end", "1")
    else:
        result.insert("end","1")

def zero():
    if 'error' in result.get() or '=' in result.get():
        result.delete(0, "end")
        result.insert("end", "0")
    else:
        result.insert("end","0")

def plus():
    if 'error' in result.get() or '=' in result.get():
        result.delete(0, "end")
        result.insert("end", "+")
    else:
        result.insert("end","+")

def minus():
    if 'error' in result.get() or '=' in result.get():
        result.delete(0, "end")
        result.insert("end", "-")
    else:
        result.insert("end","-")

def mul():
    if 'error' in result.get() or '=' in result.get():
        result.delete(0, "end")
        result.insert("end", "*")
    else:
        result.insert("end","*")

def divide():
    if 'error' in result.get() or '=' in result.get():
        result.delete(0, "end")
        result.insert("end", "/")
    else:
        result.insert("end","/")

def equal():
    if result.get() == "":
        result.insert("end", "error")
    elif result.get()[0] == "0" or result.get()[0] == "+" or result.get()[0] == "*" or result.get()[0] == "/":
        result.delete(0, "end")
        result.insert("end", "error")
    elif 'error' in result.get() or '=' in result.get():
        result.delete(0, "end")
    else:
        res = result.get()
        res = eval(res)
        result.insert("end", " = ")
        result.insert("end", res)

def clear():
    result.delete(0,"end")


#send button code
def send():
    root = tk.Tk()
    root.geometry('360x400')
    root['bg'] = 'white'

    frame4 = Frame(root, width=300, height=60, relief=RIDGE, borderwidth=5, bg="#9181ee", highlightbackground="white", highlightcolor="white", highlightthickness=2)
    frame4.place(x=0, y=0)

    l2 = Label(frame4, text="Send Bill", font=("roboto", 22, 'bold'), bg="#9181ee", fg="#ffffff")
    l2.place(x=85, y=1)

    frame5 = Frame(root, width=300, height=340, relief=RIDGE, borderwidth=5, bg="#9181ee", highlightbackground="white", highlightcolor="white", highlightthickness=2)
    frame5.place(x=0, y=55)

    innerframe5 = Frame(frame5, width=285, height=325, relief=RIDGE, borderwidth=3, bg="#9181ee", highlightbackground="white", highlightcolor="white", highlightthickness=2)
    innerframe5.place(x=3, y=3)

    l3 = Label(innerframe5, text="Send Bill Through SMS", font=("verdana", 10, 'bold'), bg="#9181ee", fg="#ffffff")
    l3.place(x=40, y=2)

    l4 = Label(innerframe5, text="Phone Number", font=("verdana", 10, 'bold'))
    l4.place(x=40, y=40)

    number = Entry(innerframe5, width=30, borderwidth=2)
    number.place(x=40, y=70)

    l5 = Label(innerframe5, text="Bill Details", font=('verdana', 10, 'bold'))
    l5.place(x=40, y=100)

    b_detail = ScrolledText(innerframe5, width=23, height=7, relief=RIDGE, borderwidth=3)
    b_detail.place(x=40, y=130)

    b_detail.insert(1.0,bill_details.get(1.0,END))
    def send_bill():
        ph_number = number.get()
        messages = b_detail.get("1.0", "end-1c")

        if ph_number == "":
            messagebox.showerror("Error", "Please fill the phone number")
        elif messages == "":
            messagebox.showerror("Error", "Bill Details is empty")
        else:
            url = "https://www.fast2sms.com/dev/bulk"
            api = "<your_api_key>"  # Replace <Your_API_Key> with your actual Fast2SMS API key
            querystring = {"authorization": api, "sender_id": "FSTSMS", "message": messages, "language": "english", "route": "p", "numbers": ph_number}
            headers = {
                'cache-control': "no-cache"
            }
            requests.request("GET", url, headers=headers, params=querystring)

            messagebox.showinfo("Send SMS", "Bill has been sent to you successfully")

    send_msg = Button(innerframe5, text="Send Bill", relief=RAISED, borderwidth=2, font=('verdana', 8, 'bold'), bg='#9181ee', fg='white', padx=20, command=send_bill)
    send_msg.place(x=100, y=255)

    root.mainloop()

#exit button code
def exit():
    message = messagebox.askquestion('Notepad',"Do you want to exit the application")
    if message == "yes":
        root.destroy()
    else:
        "return"


#clear button code
def cleared_bill():
    #foods
    chips_qty.delete(0,'end')
    chips.deselect()
    chips_qty['state'] = "disabled"
    biscuit_qty.delete(0,'end')
    biscuit.deselect()
    biscuit_qty['state'] = "disabled"
    frooti_qty.delete(0,'end')
    frooti.deselect()
    frooti_qty['state'] = "disabled"
    redbull_qty.delete(0,'end')
    redbull.deselect()
    redbull_qty['state'] = "disabled"
    cakes_qty.delete(0,'end')
    cakes.deselect()
    cakes_qty['state'] = "disabled"
    coffee_qty.delete(0,'end')
    coffee.deselect()
    coffee_qty['state'] = "disabled"
    tea_qty.delete(0,'end')
    tea.deselect()
    tea_qty['state'] = "disabled"
    milk_qty.delete(0,'end')
    milk.deselect()
    milk_qty['state'] = "disabled"
    #cosmetics
    bathsoap_qty.delete(0,'end')
    bathsoap.deselect()
    bathsoap_qty['state'] = "disabled"
    shampoo_qty.delete(0,'end')
    shampoo.deselect()
    shampoo_qty['state'] = "disabled"
    facecream_qty.delete(0,'end')
    facecream.deselect()
    facecream_qty['state'] = "disabled"
    facewash_qty.delete(0,'end')
    facewash.deselect()
    facewash_qty['state'] = "disabled"
    bodylotion_qty.delete(0,'end')
    bodylotion.deselect()
    bodylotion_qty['state'] = "disabled"
    hairclip_qty.delete(0,'end')
    hairclip.deselect()
    hairclip_qty['state'] = "disabled"
    hairband_qty.delete(0,'end')
    hairband.deselect()
    hairband_qty['state'] = "disabled"
    handwash_qty.delete(0,'end')
    handwash.deselect()
    handwash_qty['state'] = "disabled"
    #total cost
    food_cost.delete(0,'end')
    cosmetics_cost.delete(0,'end')
    paid_tax_cost.delete(0,'end')
    sub_total_cost.delete(0,'end')
    total_cost_cost.delete(0,'end')
    #bill details
    bill_details.delete(0,'end')


# Main Window code
root = tk.Tk()
root.geometry('650x400')
root.maxsize(650, 390)
root.minsize(650, 390)
root.title("Billing System")

frame = Frame(root, width=650, height=70, relief=RIDGE, borderwidth=5, bg='#9181ee')
frame.place(x=0, y=0)

l1 = Label(frame, text="Billing System", font=('roboto', 30, 'bold'), bg='#9181ee', fg='#ffffff')
l1.place(x=10, y=4)

#==================================
frame1 = Frame(root, width=450, height=230, relief=RIDGE, borderwidth=5, bg='#9181ee')
frame1.place(x=0, y=70)

innerframe1 = Frame(frame1, width=150, height=220, relief=RIDGE, borderwidth=3, bg='#9181ee', highlightbackground='white', highlightcolor='white', highlightthickness=2)
innerframe1.place(x=0, y=0)

food = LabelFrame(innerframe1, text="food", width=135, height=205, borderwidth=3, font=('verdana', 10, 'bold'), fg='#9181ee', relief=RIDGE, highlightbackground='white', highlightcolor='white', highlightthickness=2)
food.place(x=2, y=2)

chips_var = IntVar()
chips = Checkbutton(food, text="chips", variable=chips_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=chips_chk)
chips.place(x=2, y=2)
chips_qty = Entry(food, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
chips_qty.place(x=74, y=2)
chips_qty.insert(0, "0")

biscuit_var = IntVar()
biscuit = Checkbutton(food, text="biscuit", variable=biscuit_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=biscuit_chk)
biscuit.place(x=2, y=22)
biscuit_qty = Entry(food, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
biscuit_qty.place(x=74, y=22)

frooti_var = IntVar()
frooti = Checkbutton(food, text="frooti", variable=frooti_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=frooti_chk)
frooti.place(x=2, y=44)
frooti_qty = Entry(food, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
frooti_qty.place(x=74, y=44)

redbull_var = IntVar()
redbull = Checkbutton(food, text="redbull", variable=redbull_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=redbull_chk)
redbull.place(x=2, y=66)
redbull_qty = Entry(food, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
redbull_qty.place(x=74, y=66)

cakes_var = IntVar()
cakes = Checkbutton(food, text="cakes", variable=cakes_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=cakes_chk)
cakes.place(x=2, y=88)
cakes_qty = Entry(food, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
cakes_qty.place(x=74, y=88)

coffee_var = IntVar()
coffee = Checkbutton(food, text="coffee", variable=coffee_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=coffee_chk)
coffee.place(x=2, y=110)
coffee_qty = Entry(food, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
coffee_qty.place(x=74, y=110)

tea_var = IntVar()
tea = Checkbutton(food, text="tea", variable=tea_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=tea_chk)
tea.place(x=2, y=132)
tea_qty = Entry(food, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
tea_qty.place(x=74, y=132)

milk_var = IntVar()
milk = Checkbutton(food, text="milk", variable=milk_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=milk_chk)
milk.place(x=2, y=154)
milk_qty = Entry(food, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
milk_qty.place(x=74, y=154)

innerframe2 = Frame(frame1, width=290, height=220, relief=RIDGE, borderwidth=3, bg='#9181ee', highlightbackground='white', highlightcolor='white', highlightthickness=2)                       
innerframe2.place(x=151, y=0)

cosmetics = LabelFrame(innerframe2, text="cosmetics", width=275, height=205, borderwidth=3, font=('verdana', 10, 'bold'), fg='#9181ee', relief=RIDGE, highlightbackground='white', highlightcolor='white', highlightthickness=2)
cosmetics.place(x=2, y=2)

bathsoap_var = IntVar()
bathsoap = Checkbutton(cosmetics, text="bathsoap", variable=bathsoap_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=bathsoap_chk)
bathsoap.place(x=2, y=2)
bathsoap_qty = Entry(cosmetics, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
bathsoap_qty.place(x=140, y=2)

shampoo_var = IntVar()
shampoo = Checkbutton(cosmetics, text="shampoo", variable=shampoo_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=shampoo_chk)
shampoo.place(x=2, y=22)
shampoo_qty = Entry(cosmetics, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
shampoo_qty.place(x=140, y=22)

facecream_var = IntVar()
facecream = Checkbutton(cosmetics, text="facecream", variable=facecream_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=facecream_chk)
facecream.place(x=2, y=44)
facecream_qty = Entry(cosmetics, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
facecream_qty.place(x=140, y=44)

facewash_var = IntVar()
facewash = Checkbutton(cosmetics, text="facewash", variable=facewash_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=facewash_chk)
facewash.place(x=2, y=66)
facewash_qty = Entry(cosmetics, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
facewash_qty.place(x=140, y=66)

bodylotion_var = IntVar()
bodylotion = Checkbutton(cosmetics, text="bodylotion", variable=bodylotion_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=bodylotion_chk)
bodylotion.place(x=2, y=88)
bodylotion_qty = Entry(cosmetics, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
bodylotion_qty.place(x=140, y=88)

hairclip_var = IntVar()
hairclip = Checkbutton(cosmetics, text="hairclip", variable=hairclip_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=hairclip_chk)
hairclip.place(x=2, y=110)
hairclip_qty = Entry(cosmetics, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
hairclip_qty.place(x=140, y=110)

hairband_var = IntVar()
hairband = Checkbutton(cosmetics, text="hairband", variable=hairband_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=hairband_chk)
hairband.place(x=2, y=132)
hairband_qty = Entry(cosmetics, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
hairband_qty.place(x=140, y=132)

handwash_var = IntVar()
handwash = Checkbutton(cosmetics, text="handwash", variable=handwash_var, font=('verdana', 8, 'bold'), onvalue=1, offvalue=0, command=handwash_chk)
handwash.place(x=2, y=154)
handwash_qty = Entry(cosmetics, width=7, borderwidth=4, relief=SUNKEN, state='disabled')
handwash_qty.place(x=140, y=154)

#===============================
frame2 = Frame(root, width=450, height=90, relief=RIDGE, borderwidth=5, bg='#9181ee')
frame2.place(x=0, y=300)

innerframe3 = Frame(frame2, width=440, height=80, relief=RIDGE, borderwidth=3, bg='#9181ee', highlightbackground="white", highlightcolor="white", highlightthickness=2)
innerframe3.place(x=0, y=0)


cost_of_food = Label(innerframe3, text="Cost of food", font=('verdana', 8, 'bold'))
cost_of_food.place(x=2, y=2)
food_cost = Entry(innerframe3, width=13, borderwidth=4, relief=SUNKEN)
food_cost.place(x=130, y=0)

cost_of_cosmetics = Label(innerframe3, text="Cost of cosmetics", font=('verdana', 8, 'bold'))
cost_of_cosmetics.place(x=2, y=22)
cosmetics_cost = Entry(innerframe3, width=13, borderwidth=4, relief=SUNKEN)
cosmetics_cost.place(x=130, y=22)

service_charge = Label(innerframe3, text="Service Charge", font=('verdana', 8, 'bold'))
service_charge.place(x=2, y=46)
service_charge_cost = Entry(innerframe3, width=13, borderwidth=4, relief=SUNKEN)
service_charge_cost.place(x=130, y=46)

paid_tax = Label(innerframe3, text="Paid Tax", font=('verdana', 8, 'bold'))
paid_tax.place(x=250, y=2)
paid_tax_cost = Entry(innerframe3, width=13, borderwidth=4, relief=SUNKEN)
paid_tax_cost.place(x=330, y=0)

sub_total = Label(innerframe3, text="Sub Total", font=('verdana', 8, 'bold'))
sub_total.place(x=250, y=24)
sub_total_cost = Entry(innerframe3, width=13, borderwidth=4, relief=SUNKEN)
sub_total_cost.place(x=330, y=22)

total_cost = Label(innerframe3, text="Total Cost", font=('verdana', 8, 'bold'))
total_cost.place(x=250, y=46)
total_cost_cost = Entry(innerframe3, width=13, borderwidth=4, relief=SUNKEN)
total_cost_cost.place(x=330, y=44)


#===========================================
frame3 = Frame(root, width=200, height=320, relief=RIDGE, borderwidth=5, bg="#9181ee")
frame3.place(x=450, y=70)

innerframe4 = Frame(frame3, width=190, height=310, relief=RIDGE, borderwidth=3, bg="#9181ee", highlightbackground="white", highlightcolor="white", highlightthickness=2)
innerframe4.place(x=0, y=0)

result = Entry(innerframe4, width=28, relief=SUNKEN, borderwidth=3)
result.place(x=0, y=0)

nine = Button(innerframe4, text="9", padx=15, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='#9181ee', fg="white", command=nine)
nine.place(x=0, y=24)
eight = Button(innerframe4, text="8", padx=15, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='#9181ee', fg="white", command=eight)
eight.place(x=48, y=24)
seven = Button(innerframe4, text="7", padx=15, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='#9181ee', fg="white", command=seven)
seven.place(x=96, y=24)
plus = Button(innerframe4, text="+", padx=6, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='white', fg="black", command=plus)
plus.place(x=144, y=24)

six = Button(innerframe4, text="6", padx=15, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='#9181ee', fg="white", command=six)
six.place(x=0, y=50)
five = Button(innerframe4, text="5", padx=15, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='#9181ee', fg="white", command=five)
five.place(x=48, y=50)
four = Button(innerframe4, text="4", padx=15, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='#9181ee', fg="white", command=four)
four.place(x=96, y=50)
minus = Button(innerframe4, text="-", padx=8, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='white', fg="black", command=minus)
minus.place(x=144, y=50)

three = Button(innerframe4, text="3", padx=15, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='#9181ee', fg="white", command=three)
three.place(x=0, y=76)
two = Button(innerframe4, text="2", padx=15, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='#9181ee', fg="white", command=two)
two.place(x=48, y=76)
one = Button(innerframe4, text="1", padx=15, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='#9181ee', fg="white", command=one)
one.place(x=96, y=76)
multiply = Button(innerframe4, text="*", padx=7, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='white', fg="black", command=mul)
multiply.place(x=144, y=76)

zero = Button(innerframe4, text="0", padx=15, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='#9181ee', fg="white", command=zero)
zero.place(x=0, y=102)
clear = Button(innerframe4, text="C", padx=15, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='#9181ee', fg="white", command=clear)
clear.place(x=48, y=102)
equal = Button(innerframe4, text="=", padx=15, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='#9181ee', fg="white", command=equal)
equal.place(x=96, y=102)
divide = Button(innerframe4, text="/", padx=7, relief=RAISED, borderwidth=2, font=('verdana', 10, 'bold'), bg='white', fg="black", command=divide)
divide.place(x=144, y=102)


bill_details = ScrolledText(innerframe4, width=23, height=9, relief= SUNKEN, borderwidth=3, font=("courier", 9,''))
bill_details.place(x=0, y=130)

total = Button(innerframe4, text="Total", relief=RAISED, borderwidth=2, font=('verdana', 8, 'bold'), bg='#9181ee', fg="white", command=total_bills)
total.place(x=0, y=275)

save = Button(innerframe4, text="Save", relief=RAISED, borderwidth=2, font=('verdana', 8, 'bold'), bg='#9181ee', fg="white", command=save)
save.place(x=43, y=275)

send = Button(innerframe4, text="Send", relief=RAISED, borderwidth=2, font=('verdana', 8, 'bold'), bg='#9181ee', fg="white", command=send)
send.place(x=82, y=275)

exit = Button(innerframe4, text="Exit", relief=RAISED, borderwidth=2, font=('verdana', 8, 'bold'), bg='#9181ee', fg="white", command=exit)
exit.place(x=124, y=275)

clr = Button(innerframe4, text="C", relief=RAISED, borderwidth=2, font=('verdana', 8, 'bold'), bg='#9181ee', fg="white", command=cleared_bill)
clr.place(x=160, y=275)

root.mainloop()
